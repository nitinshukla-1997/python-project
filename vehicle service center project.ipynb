# %%
class fine_service:
    def __init__(fs):
        print("\t\t\t\t fine service ")
        print("\t\t\t\t since-1947")
        print("\t\t\t contact-9785104933")
        print("\n\n\t\t service list")
        x=["parking","washing","repairing","colouring"]
        for k in x:
            print("\n\n",k)
                               
        a=input("want to see location(yes/no):")
        if a=="yes":
            import cv2 as cv
            capture=cv.VideoCapture(r"C:\Users\anshu\Downloads\BB_3c23c29b-fcf8-4afc-b0d5-3ce8b51a124a.mov")
            while True:
                isTrue,frame=capture.read()
                cv.imshow("Video",frame)
                if cv.waitKey(15) & 0xff==ord("a"):
                    break
    

        

    
    def parking(fs):
        x=["car","bicycle","bike","truck","auto"]
        y=[50,20,30,100,75]
        parking_={"parking":x,"price":y}
        import pandas as pd
        df=pd.DataFrame(parking_)
        print("\n\n parking \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("enter the value position:"))
            c=int(input("enter the quantity:"))
            z=parking_["price"][b]
            y=z*c
            d.append(y)
            x=input("you want to park antoher vehcile(yes/no):")
            if(x=="no"):
                print("thank you")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax= 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupess")
        
        p_m=input("enter the choice(online/cash):")
        if p_m=="online":
            import cv2 as cv
            QR=cv.imread(r"C:\Users\anshu\Downloads\img1.png")
            cv.imshow("qr",QR)
            cv.waitKey(0)
        else:
            print("take cash receipt")
        

    def washing(fs):
        x=["car","bicycle","bike","truck","auto"]
        y=[50,20,30,100,75]
        washing_={"washing":x,"price":y}
        import pandas as pd
        df=pd.DataFrame(washing_)
        print("\n\n washing \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("enter the value position:"))
            c=int(input("enter the quantity:"))
            z=washing_["price"][b]
            y=z*c
            d.append(y)
            x=input("you want to wash antoher vehcile(yes/no):")
            if(x=="no"):
                print("thank you")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax= 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupess")
        
        p_m=input("enter the choice(online/cash):")
        if p_m=="online":
            import cv2 as cv
            QR=cv.imread(r"C:\Users\anshu\Downloads\img1.png")
            cv.imshow("qr",QR)
            cv.waitKey(0)
        else:
            print("take cash receipt")
        
         

    def repairing(fs):
        x=["car","bicycle","bike","truck","auto"]
        y=[50,20,30,100,75]
        repairing_={"repairing":x,"price":y}
        import pandas as pd
        df=pd.DataFrame(repairing_)
        print("\n\n repairing \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("enter the value position:"))
            c=int(input("enter the quantity:"))
            z=repairing_["price"][b]
            y=z*c
            d.append(y)
            x=input("you want to repair antoher vehcile(yes/no):")
            if(x=="no"):
                print("thank you")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax= 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupess")
        
        p_m=input("enter the choice(online/cash):")
        if p_m=="online":
            import cv2 as cv
            QR=cv.imread(r"C:\Users\anshu\Downloads\img1.png")
            cv.imshow("qr",QR)
            cv.waitKey(0)
        else:
            print("take cash receipt")
        
         

    def colouring(fs):
        x=["car","bicycle","bike","truck","auto"]
        y=[50,20,30,100,75]
        colouring_={"colouring":x,"price":y}
        import pandas as pd
        df=pd.DataFrame(colouring_)
        print("\n\n colouring \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("enter the value position:"))
            c=int(input("enter the quantity:"))
            z=colouring_["price"][b]
            y=z*c
            d.append(y)
            x=input("you want to colour antoher vehcile(yes/no):")
            if(x=="no"):
                print("thank you")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        print("servicetax= 5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupess")
        
        p_m=input("enter the choice(online/cash):")
        if p_m=="online":
            import cv2 as cv
            QR=cv.imread(r"C:\Users\anshu\Downloads\img1.png")
            cv.imshow("qr",QR)
            cv.waitKey(0)
        else:
            print("take cash receipt")

# %%
obj=fine_service()
# Out:
# 				 fine service
# 				 since-1947
# 			 contact-9785104933
#
#
# 		 service list
#
#
#  parking
#
#
#  washing
#
#
#  repairing
#
#
#  colouring
# want to see location(yes/no): no

# %%
x=input("enter the service name:")
if x=="parking":
    print(obj.parking())
elif x=="washing":
    print(obj.washing())
elif x=="repairing":
    print(obj.repairing())
elif x=="colouring":
    print(obj.colouring())
else:
    print("click right option: \n dhaneybaad:")
# Out:
# enter the service name: parking
#  parking
#
#
#    parking  price
# 0      car     50
# 1  bicycle     20
# 2     bike     30
# 3    truck    100
# 4     auto     75
# enter the value position: 1
# enter the quantity: 2
# you want to park antoher vehcile(yes/no): no
# thank you
# servicetax= 5%
# Total Amount: 40 Rupees
# Total Amount Including Service Tax: 42.0 Rupess
# enter the choice(online/cash): online
